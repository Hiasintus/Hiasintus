# %%
def harga(a,b):
    if a=="SP":
        return 7000*b
    elif a=="PB":
        return 8000*b
    elif a=="PA":
        return 11000*b
    elif a=="DD":
        return 11000*b
    elif a=="FF":
        return 7000*b
    elif a=="NS":
        return 4000*b
def hargasatuan(a):
    if a=="SP":
        return 7000
    elif a=="PB":
        return 8000
    elif a=="PA":
        return 11000
    elif a=="DD":
        return 11000
    elif a=="FF":
        return 7000
    elif a=="NS":
        return 4000


def cek(a):
    x=1
    x2=2
    z3=True
    c=["SP","PB","PA","DD","FF","NS"]
    d=0
    while(z3):
        if a== c[d]:
            return x
            z3=False
        elif a!=c[d]:
            if d<len(c):
                d=d+1
            else:
                return x2
        
            
from prettytable import PrettyTable
z= True
x=1
while z:
    x=int(input("masukkan banyak jenis: "))
    if x<7:
        z=False
    else:
        print("input ulang, terjadi kesalahan penginputan")

output=[]
data=[]
print (x)
z=True
b=0

while z:
    z1=True
    a=0
    while z1:
        print("jenis ke - ", b+1)
        data.append(b+1)
        y=str(input("inputkan kode potongan: "))
        if cek(y)== 1:
            data.append(y)
            z1=False
            BPotongan=int(input("banyak potongan: " ))
            data.append(hargasatuan(y))
            data.append(BPotongan)
            data.append(harga(y,BPotongan))
            output.append(data)
            a=a+harga(y,BPotongan)
            data=[]
        else:
            print("harap input kembali")
        
        
    b=b+1
    if b==x:
        z=False
mytable=PrettyTable(["no potongan","jenis","harga satuan","banyak beli", "jumlah"])
for i in range(len(output)):
    mytable.add_row(output[i])
print (mytable)
print("jumlah bayar :",a)
print("pajak 10% : ",a*(10/100))
print("Total bayar: ",a+(a*(10/100)))
# Out:
# masukkan banyak jenis: 3
# 3
# jenis ke -  1
# inputkan kode potongan: PB
# banyak potongan: 3
# jenis ke -  2
# inputkan kode potongan: NS
# banyak potongan: 4
# jenis ke -  3
# inputkan kode potongan: PB
# banyak potongan: 3
# +-------------+-------+--------------+-------------+--------+
# | no potongan | jenis | harga satuan | banyak beli | jumlah |
# +-------------+-------+--------------+-------------+--------+
# |      1      |   PB  |     8000     |      3      | 24000  |
# |      2      |   NS  |     4000     |      4      | 16000  |
# |      3      |   PB  |     8000     |      3      | 24000  |
# +-------------+-------+--------------+-------------+--------+
# jumlah bayar : 24000
# pajak 10% :  2400.0
# Total bayar:  26400.0
